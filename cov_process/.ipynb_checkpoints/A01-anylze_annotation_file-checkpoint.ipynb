# %%
# This script read and parse the annotation file and find out if all genes has principle transcripts, \
# than compare to PCAWG genes
# Author: Yiyun

import pandas as pd

# %%
f_anno = ('../anno_ref/gencode_v19/gencode.v19.annotation.gtf')
f_gene = ('../anno_ref/gene-PCAWG-all.tsv')

# %%
df_gtf = pd.read_csv(f_anno, skiprows =[0,1,2,3,4], header = None, sep='\t')
df_info_expand = df_gtf[8].str.split(';', expand = True)
df_gtf.drop(8, axis=1, inplace=True)
df_gtf = pd.concat([df_gtf,df_info_expand], axis = 1)
df_gtf.columns =range(0,len(df_gtf.columns) )
# Out:
#           1     2       3       4  5  6  7                            8   \
# 21    HAVANA  gene   14363   29806  .  -  .  gene_id "ENSG00000227232.4"
# 82    HAVANA  gene   29554   31109  .  +  .  gene_id "ENSG00000243485.2"
# 92    HAVANA  gene   34554   36081  .  -  .  gene_id "ENSG00000237613.2"
# 100   HAVANA  gene   52473   54936  .  +  .  gene_id "ENSG00000268020.2"
# 106   HAVANA  gene   62948   63887  .  +  .  gene_id "ENSG00000240361.1"
# 109   HAVANA  gene   69091   70008  .  +  .  gene_id "ENSG00000186092.4"
# 116   HAVANA  gene   89295  133566  .  -  .  gene_id "ENSG00000238009.2"
# 134   HAVANA  gene   89551   91105  .  -  .  gene_id "ENSG00000239945.1"
# 138   HAVANA  gene  131025  134836  .  +  .  gene_id "ENSG00000233750.3"
# 141  ENSEMBL  gene  134901  139379  .  -  .  gene_id "ENSG00000237683.5"
# 150   HAVANA  gene  135141  135895  .  -  .  gene_id "ENSG00000268903.1"
# 153   HAVANA  gene  137682  137965  .  -  .  gene_id "ENSG00000269981.1"
# 156   HAVANA  gene  139790  140339  .  -  .  gene_id "ENSG00000239906.1"
# 160   HAVANA  gene  141474  173862  .  -  .  gene_id "ENSG00000241860.2"
#
#                                      9                                  10  \
# 21    transcript_id "ENSG00000227232.4"             gene_type "pseudogene"
# 82    transcript_id "ENSG00000243485.2"                gene_type "lincRNA"
# 92    transcript_id "ENSG00000237613.2"                gene_type "lincRNA"
# 100   transcript_id "ENSG00000268020.2"             gene_type "pseudogene"
# 106   transcript_id "ENSG00000240361.1"             gene_type "pseudogene"
# 109   transcript_id "ENSG00000186092.4"         gene_type "protein_coding"
# 116   transcript_id "ENSG00000238009.2"                gene_type "lincRNA"
# 134   transcript_id "ENSG00000239945.1"                gene_type "lincRNA"
# 138   transcript_id "ENSG00000233750.3"             gene_type "pseudogene"
# 141   transcript_id "ENSG00000237683.5"         gene_type "protein_coding"
# 150   transcript_id "ENSG00000268903.1"             gene_type "pseudogene"
# 153   transcript_id "ENSG00000269981.1"             gene_type "pseudogene"
# 156   transcript_id "ENSG00000239906.1"              gene_type "antisense"
# 160   transcript_id "ENSG00000241860.2"   gene_type "processed_transcript"
#
#                        11                          12  \
# 21    gene_status "KNOWN"          gene_name "WASH7P"
# 82    gene_status "NOVEL"      gene_name "MIR1302-11"
# 92    gene_status "KNOWN"         gene_name "FAM138A"
# 100   gene_status "KNOWN"          gene_name "OR4G4P"
# 106   gene_status "KNOWN"         gene_name "OR4G11P"
# 109   gene_status "KNOWN"           gene_name "OR4F5"
# 116   gene_status "NOVEL"    gene_name "RP11-34P13.7"
# 134   gene_status "NOVEL"    gene_name "RP11-34P13.8"
# 138   gene_status "KNOWN"          gene_name "CICP27"
# 141   gene_status "KNOWN"      gene_name "AL627309.1"
# 150   gene_status "KNOWN"   gene_name "RP11-34P13.15"
# 153   gene_status "KNOWN"   gene_name "RP11-34P13.16"
# 156   gene_status "NOVEL"   gene_name "RP11-34P13.14"
# 160   gene_status "NOVEL"   gene_name "RP11-34P13.13"
#
#                                           13                          14  \
# 21              transcript_type "pseudogene"   transcript_status "KNOWN"
# 82                 transcript_type "lincRNA"   transcript_status "NOVEL"
# 92                 transcript_type "lincRNA"   transcript_status "KNOWN"
# 100             transcript_type "pseudogene"   transcript_status "KNOWN"
# 106             transcript_type "pseudogene"   transcript_status "KNOWN"
# 109         transcript_type "protein_coding"   transcript_status "KNOWN"
# 116                transcript_type "lincRNA"   transcript_status "NOVEL"
# 134                transcript_type "lincRNA"   transcript_status "NOVEL"
# 138             transcript_type "pseudogene"   transcript_status "KNOWN"
# 141         transcript_type "protein_coding"   transcript_status "KNOWN"
# 150             transcript_type "pseudogene"   transcript_status "KNOWN"
# 153             transcript_type "pseudogene"   transcript_status "KNOWN"
# 156              transcript_type "antisense"   transcript_status "NOVEL"
# 160   transcript_type "processed_transcript"   transcript_status "NOVEL"
#
#                                    15        16  \
# 21           transcript_name "WASH7P"   level 2
# 82       transcript_name "MIR1302-11"   level 2
# 92          transcript_name "FAM138A"   level 2
# 100          transcript_name "OR4G4P"   level 2
# 106         transcript_name "OR4G11P"   level 2
# 109           transcript_name "OR4F5"   level 2
# 116    transcript_name "RP11-34P13.7"   level 2
# 134    transcript_name "RP11-34P13.8"   level 2
# 138          transcript_name "CICP27"   level 1
# 141      transcript_name "AL627309.1"   level 3
# 150   transcript_name "RP11-34P13.15"   level 2
# 153   transcript_name "RP11-34P13.16"   level 2
# 156   transcript_name "RP11-34P13.14"   level 2
# 160   transcript_name "RP11-34P13.13"   level 2
#
#                                       17                                   18  \
# 21    havana_gene "OTTHUMG00000000958.1"
# 82    havana_gene "OTTHUMG00000000959.2"
# 92    havana_gene "OTTHUMG00000000960.1"
# 100   havana_gene "OTTHUMG00000185779.1"
# 106   havana_gene "OTTHUMG00000001095.2"
# 109   havana_gene "OTTHUMG00000001094.1"
# 116   havana_gene "OTTHUMG00000001096.2"
# 134   havana_gene "OTTHUMG00000001097.2"
# 138                 tag "pseudo_consens"   havana_gene "OTTHUMG00000001257.3"
# 141                                                                      None
# 150   havana_gene "OTTHUMG00000182518.2"
# 153   havana_gene "OTTHUMG00000182738.2"
# 156   havana_gene "OTTHUMG00000002481.1"
# 160                     tag "ncRNA_host"   havana_gene "OTTHUMG00000002480.3"
#
#        19
# 21   None
# 82   None
# 92   None
# 100  None
# 106  None
# 109  None
# 116  None
# 134  None
# 138
# 141  None
# 150  None
# 153  None
# 156  None
# 160

# %%
df_allgene = df_gtf[df_gtf[13].str.contains('protein_coding') & df_gtf[14].str.contains('KNOWN')& df_gtf[2].str.contains('gene')]
print 'Number of all KNOWN PROTEIN CODING GENES in GENCODE GTF FILES: '+ str(len(df_allgene))
# Out:
# Number of all KNOWN PROTEIN CODING GENES in GENCODE GTF FILES: 19456

# %%
# read in all genes in PCAWG in a list
list_pcawg = []
with open(f_gene,'r') as gf:
    for lines in gf:
        list_pcawg.append(lines.strip('\n'))

# %%
print 'Number of genes in GTF file but not in PCAWG: '+\
str(len(df_allgene[~df_allgene[12].str.split("\"",expand = True)[1].isin(list_pcawg)].iloc[:,1:15]))
# Out:
# Number of genes in GTF file but not in PCAWG: 75

# %%
list_png = []
df_gene = df_allgene[12].str.split("\"",expand = True)[1]
for genes in list_pcawg:
    if not any(df_gene==genes):
        if genes not in list_png:
            list_png.append(genes)

# %%
print 'Number of genes in PCAWG file but not in GTF: '+\
str(len(list_png))
# Out:
# Number of genes in PCAWG file but not in GTF: 850

# %%
print 'Number of duplicated genes in GTF file: '+ str(len(df_duplicate[df_duplicate[12].\
                                                str.split("\"",expand = True)[1].isin(list_pcawg)].iloc[:,1:15]))
# Out:
# 45

# %%
df_agnd = df_allgene[~df_allgene[12].str.split("\"",expand = True)[1].duplicated()]
df_agndinp = df_agnd[df_agnd[12].str.split("\"",expand = True)[1].isin(list_pcawg)]

# %%
df_finalg = df_agndinp[12].str.split("\"",expand = True)[1]

# %%
df_finalg.to_csv('../anno_ref/genes-final.csv', index=False, header=False)
