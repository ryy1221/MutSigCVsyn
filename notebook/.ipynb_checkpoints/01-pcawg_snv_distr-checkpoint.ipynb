# %%
# this code plot the distribution of PCAWG sample snv numbers
# Author: Yiyun
# data: Aug 20th
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load file
pcawg_info = '../anno_ref/PCAWG_sample_info.txt'
df_pcawg = pd.read_csv(pcawg_info,sep='\t')

# %%
ax = df_pcawg['all.SNVs'].plot.hist(bins=200, alpha=0.5)
plt.show()
#magnify the first few columns
ax = df_pcawg['all.SNVs'].plot.hist(bins=200, alpha=0.5)
plt.xlim(0,100000)
plt.show()
