# %%
# This script do p value correction for synonymous outputs
# Author Yiyun
import pandas as pd
from os.path import join, isdir, exists
from os import listdir, remove
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.cbook import boxplot_stats

# %%
nsyn_dir = '../mutsig_out/nsyn/out08262020'
syn_dir = '../mutsig_out/syn/out08262020'
cov_syn_dir = '../org_cov_maf'
cov_nsyn_dir = '../org_cov_maf'

# %%
# Synonymous p value distribution drop p value =1
for org in listdir(syn_dir):
    if '-' not in org:
        cov_f = join(cov_syn_dir,org,'merged_'+org+'.txt')
        df_cov = pd.read_csv(cov_f,sep = '\t', nrows =1)
        org_dir = join(syn_dir,org)
        for f in listdir(org_dir):
            if f.endswith('sig_genes.txt'):
                f_dir = join(org_dir,f)
                df_org = pd.read_csv(f_dir,sep = '\t', index_col=0)
                df_org.loc[df_org['p']==0, 'p'] = 1e-50
                df_p = -np.log10(df_org['p'].dropna())
                sns.distplot(df_p, bins=50, kde=False, rug=True).set_title('syn_'+org+': '+str(len(df_cov.columns)-3))
                plt.show()
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-16-91e392753ea4> in <module>()
#      11                 df_org.loc[df_org['p']==0, 'p'] = 1e-50
#      12                 df_p = -np.log10(df_org['p'].dropna())
# ---> 13                 sns.distplot(df_p, bins=50, kde=False, rug=True).set_title('syn_'+org+': '+str(len(df_cov.columns)-3))
#      14                 plt.show()
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     225         rug_color = rug_kws.pop("color", color)
#     226         axis = "y" if vertical else "x"
# --> 227         rugplot(a, axis=axis, ax=ax, color=rug_color, **rug_kws)
#     228         if rug_color != color:
#     229             rug_kws["color"] = rug_color
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/seaborn/distributions.pyc in rugplot(a, height, axis, ax, **kwargs)
#     674     kwargs.setdefault("linewidth", 1)
#     675     for pt in a:
# --> 676         func(pt, 0, height, **kwargs)
#     677
#     678     return ax
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in axvline(self, x, ymin, ymax, **kwargs)
#     798         l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     799         self.add_line(l)
# --> 800         self.autoscale_view(scalex=scalex, scaley=False)
#     801         return l
#     802
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in autoscale_view(self, tight, scalex, scaley)
#    2240             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2241             x_stickies = sum([sticky.x for sticky in stickies], [])
# -> 2242             y_stickies = sum([sticky.y for sticky in stickies], [])
#    2243             if self.get_xscale().lower() == 'log':
#    2244                 x_stickies = [xs for xs in x_stickies if xs > 0]
#
# KeyboardInterrupt:

# %%
# Synonymous p value distribution drop p value =1
for org in listdir(syn_dir):
    if '-' not in org:
        cov_f = join(cov_syn_dir,org,'merged_'+org+'.txt')
        df_cov = pd.read_csv(cov_f,sep = '\t', nrows =1)
        org_dir = join(syn_dir,org)
        for f in listdir(org_dir):
            if f.endswith('sig_genes.txt'):
                f_dir = join(org_dir,f)
                df_org = pd.read_csv(f_dir,sep = '\t', index_col=0)
                df_org = df_org[df_org['x']>=10]
                df_org.loc[df_org['p']==0, 'p'] = 1e-50
                df_p = -np.log10(df_org[df_org['p']<1]['p'])
                
                #plot boxplot
                f, ax = plt.subplots(figsize=(15,15))
                ax = sns.boxplot(df_p)
                ax.set_title('syn_'+org+': '+str(len(df_cov.columns)-3))
                
                #label outliers
                outliers = [y for stat in boxplot_stats(df_p) for y in stat['fliers']]
                o_df = pd.DataFrame(columns = ['gene','pval'])
                for outlier in outliers:
                    idx = df_org[-np.log10(df_org['p']) == outlier].index.values[0]
                    tmp = pd.DataFrame([[idx,outlier]],columns = ['gene','pval'] )
                    o_df = o_df.append(tmp,ignore_index=True)

                for row in o_df.iterrows():
                    ax.annotate(row[1]['gene'], xy=(row[1]['pval'],0.1), xytext=(0,1), textcoords='offset points', fontsize=10, rotation=90)

                #sns.distplot(df_p, bins=50, kde=False, rug=False).set_title('syn_'+org+': '+str(len(df_cov.columns)-3))
                plt.show()

# %%
ax = sns.boxplot(df_p)

outliers = [y for stat in boxplot_stats(df_p) for y in stat['fliers']]
o_df = pd.DataFrame(columns = ['gene','pval'])
for outlier in outliers:
    idx = df_org[-np.log10(df_org['p']) == outlier].index.values[0]
    tmp = pd.DataFrame([[idx,outlier]],columns = ['gene','pval'] )
    o_df = o_df.append(tmp,ignore_index=True)

for row in o_df.iterrows():
    ax.annotate(row[1]['gene'], xy=(row[1]['pval'],0.5), xytext=(2,2), textcoords='offset points', fontsize=14)

plt.show()

# %%
# Nonsynonymous p value distribution drop p value =1
for org in listdir(nsyn_dir):
    if '-' not in org:
        cov_f = join(cov_nsyn_dir,org,'merged_'+org+'.txt')
        df_cov = pd.read_csv(cov_f,sep = '\t', nrows =1)
        org_dir = join(nsyn_dir,org)
        for f in listdir(org_dir):
            if f.endswith('sig_genes.txt'):
                f_dir = join(org_dir,f)
                df_org = pd.read_csv(f_dir,sep = '\t', index_col=0)
                df_org.loc[df_org['p']==0, 'p'] = 1e-50
                sns.distplot(-np.log10(df_org['p'].dropna()), bins=50, kde=False, rug=True).set_title('syn_'+org+': '+str(len(df_cov.columns)-3))                
                plt.show()
# Out:
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log10
#   # This is added back by InteractiveShellApp.init_path()
# ValueErrorTraceback (most recent call last)
# <ipython-input-12-cd20d3c8aaaa> in <module>()
#       9                 f_dir = join(org_dir,f)
#      10                 df_org = pd.read_csv(f_dir,sep = '\t', index_col=0)
# ---> 11                 sns.distplot(-np.log10(df_org[df_org['p']<1]['p']), bins=50, kde=False, rug=True).set_title('nsyn_'+org+': '+str(len(df_cov.columns)-3))
#      12                 plt.show()
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     212         hist_color = hist_kws.pop("color", color)
#     213         ax.hist(a, bins, orientation=orientation,
# --> 214                 color=hist_color, **hist_kws)
#     215         if hist_color != color:
#     216             hist_kws["color"] = hist_color
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(***failed resolving arguments***)
#    6205             # this will automatically overwrite bins,
#    6206             # so that each histogram uses the same bins
# -> 6207             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6208             m = m.astype(float)  # causes problems later if it's an int
#    6209             if mlast is None:
#
# /opt/aci/sw/python/2.7.14_anaconda-5.0.1/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     668     if not np.all(np.isfinite([mn, mx])):
#     669         raise ValueError(
# --> 670             'range parameter must be finite.')
#     671     if mn == mx:
#     672         mn -= 0.5
#
# ValueError: range parameter must be finite.
