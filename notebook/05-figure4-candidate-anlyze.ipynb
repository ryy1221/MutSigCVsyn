# %%
### This note book analyze figure 5 - synonymous candidate result
# Author: Yiyun

import pandas as pd
import os,pickle
import numpy as np
from collections import Counter

# %% [markdown]
# ***
# ### Synonymous candidates in CGC - TSG, oncogenes...

# %%
### Read synonymous candidate list and create pivot table for genes
cohorts = ['histology','organ','origin','system','pancancer']
dir_out = './figure4/'

# Read the significant gene dataframe after FDR calculation
feature_type = 'histology';syn_nsyn = 'syn';run = 'cohort_072221';threshold = 1;
df_syn = pd.read_csv(os.path.join(dir_out,feature_type+'.syn.df_all_forheatmap.'+run+'.'+str(threshold)+'.csv'),index_col = 0)
df_syn['FDR'] = -np.log10(df_syn['FDR']) # Transform into log scale

### read the census gene file and get cancer census gene list
dir_anno = '../anno_ref/anlyze-manuscript'
df_census = pd.read_csv(os.path.join(dir_anno,'Census_all.csv'))
df_census = df_census.set_index('Gene Symbol')

# %%
### Find overlap between synonymous candidate and CGC genes
df_incgc = pd.DataFrame() # Dataframe for gene that is in Cancer Gene Census
for gene in df_syn['gene']:
    if gene in df_census.index.tolist():
        df_incgc = pd.concat([df_incgc,df_census.loc[gene]], axis = 1)

# %%
df_incss
# Out:
#                                                                     BCL2  \
# Name                                               B-cell CLL/lymphoma 2
# Entrez GeneId                                                        596
# Genome Location                                     18:63123346-63320128
# Tier                                                                   1
# Hallmark                                                             NaN
# Chr Band                                                           21.33
# Somatic                                                              yes
# Germline                                                             NaN
# Tumour Types(Somatic)                                           NHL, CLL
# Tumour Types(Germline)                                               NaN
# Cancer Syndrome                                                      NaN
# Tissue Type                                                            L
# Molecular Genetics                                                   Dom
# Role in Cancer                                          oncogene, fusion
# Mutation Types                                                         T
# Translocation Partner                                                IGH
# Other Germline Mut                                                   NaN
# Other Syndrome                                                       NaN
# Synonyms                596,BCL2,Bcl-2,ENSG00000171791.12,P10415,PPP1R50
#
#                                                                      CALR  \
# Name                                                         calreticulin
# Entrez GeneId                                                         811
# Genome Location                                      19:12938607-12944489
# Tier                                                                    1
# Hallmark                                                              Yes
# Chr Band                                                            13.13
# Somatic                                                               yes
# Germline                                                              NaN
# Tumour Types(Somatic)                                            MPN, MDS
# Tumour Types(Germline)                                                NaN
# Cancer Syndrome                                                       NaN
# Tissue Type                                                             L
# Molecular Genetics                                                    Dom
# Role in Cancer                                                   oncogene
# Mutation Types                                                     F, Mis
# Translocation Partner                                                 NaN
# Other Germline Mut                                                    NaN
# Other Syndrome                                                        NaN
# Synonyms                811,CALR,CRT,ENSG00000179218.13,FLJ26680,P2779...
#
#                                                                      NACA
# Name                    nascent-polypeptide-associated complex alpha p...
# Entrez GeneId                                                        4666
# Genome Location                                      12:56712433-56725299
# Tier                                                                    2
# Hallmark                                                              NaN
# Chr Band                                                             13.3
# Somatic                                                               yes
# Germline                                                              NaN
# Tumour Types(Somatic)                                                 NHL
# Tumour Types(Germline)                                                NaN
# Cancer Syndrome                                                       NaN
# Tissue Type                                                             L
# Molecular Genetics                                                    Dom
# Role in Cancer                                                     fusion
# Mutation Types                                                          T
# Translocation Partner                                                BCL6
# Other Germline Mut                                                    NaN
# Other Syndrome                                                        NaN
# Synonyms                        4666,E9PAV3,ENSG00000196531.10,NACA,NACA1

# %% [markdown]
# ***
# ### Analyze synonymous mutations in the candidate gene list

# %%
out_dir = './figure5'

# %%
### Read synonymous candidate list and create pivot table for genes
cohorts = ['histology','organ','origin','system','pancancer']
dir_out = './figure4/'

dir_maf = '../maf_out/maf_cohorts_060121'
feature_type = 'histology'

# Read the significant gene dataframe after FDR calculation
feature_type = 'histology';syn_nsyn = 'syn';run = 'cohort_072221';threshold = 1;
df_syn = pd.read_csv(os.path.join(dir_out,feature_type+'.syn.df_all_forheatmap.'+run+'.'+str(threshold)+'.csv'),index_col = 0)
df_syn = df_syn.set_index('gene')

# %%
df_syn
# Out:
#                 X         p         q              feature exp.nonexp  \
# gene
# BCL2            0  0.000000  0.000000           Lymph-BNHL        exp
# ITLN1       54504  0.000000  0.000000        CNS-PiloAstro        exp
# XIRP2      109020  0.000000  0.000000        Skin-Melanoma        exp
# SOX18      272521  0.000000  0.000000          Eso-AdenoCA        exp
# SIGLEC15   345195  0.000000  0.000000         Panc-AdenoCA        exp
# TP53I3     345196  0.000000  0.000000         Panc-AdenoCA        exp
# CALR       399696  0.000000  0.000000       Uterus-AdenoCA        exp
# PPWD1      417864  0.000000  0.000000             Head-SCC        exp
# PURA       563208  0.000000  0.000000       Breast-AdenoCA        exp
# HIST1H2BK       1  0.000002  0.014953           Lymph-BNHL        exp
# AKAP2      417865  0.000004  0.036627             Head-SCC        exp
# NOL9            2  0.000008  0.051304           Lymph-BNHL        exp
# NACA       109027  0.000017  0.016218        Skin-Melanoma        exp
# DMRTB1     345197  0.000018  0.057219         Panc-AdenoCA        exp
# ACTRT2     109028  0.000031  0.027983        Skin-Melanoma        exp
# ITPR2      145344  0.000034  0.660031  SoftTissue-Liposarc        exp
# ACVRL1     581377  0.000045  0.435663        Prost-AdenoCA        exp
# TPM2       254352  0.000060  1.000000     Breast-LobularCA        exp
# SH3BGR      36336  0.000061  1.000000       Panc-Endocrine        exp
# ZFP69      145345  0.000072  0.691311  SoftTissue-Liposarc        exp
#
#                     FDR
# gene
# BCL2       1.518254e-18
# ITLN1      1.518254e-18
# XIRP2      1.518254e-18
# SOX18      1.518254e-18
# SIGLEC15   1.518254e-18
# TP53I3     1.518254e-18
# CALR       1.518254e-18
# PPWD1      1.518254e-18
# PURA       1.518254e-18
# HIST1H2BK  5.211509e-18
# AKAP2      3.059533e-17
# NOL9       7.729580e-16
# NACA       5.010575e-13
# DMRTB1     9.937688e-13
# ACTRT2     3.201434e-09
# ITPR2      2.631870e-08
# ACVRL1     5.643940e-06
# TPM2       1.128742e-03
# SH3BGR     1.593320e-03
# ZFP69      2.173972e-02

# %% [markdown]
# **Analyze individual genes**
# 1. ITLN1: Cancer gene, but no literature support it's role in CNS-PiloAstro. The synonymous mutation is also found in TCGA
# 2. XIRP2: Surrogate of UV exposure. Could explain so many synonymous mutations? However, patients with mutations in these genes seem to liver longer,, the other 9 affected genes' ranking? and the patient disease subtype
# 3. SOX18: Had been found upregulated in other cancer types and related to poor prognostic. The HMG domain binds transcription factors.
# 4. SIGLEC15: Related to Immune system, and seems high expression lower survival rate -- new star
# 5. TP53I3: downstream of P53? seems may have a role but not fully studied
# 6. CALR: protein upregulated in subtypes?
# 7. PPWD1: shallow work from other cancer types
# 8. HIST1H2BK: potential role in other tumor types
# 9. AKAP2: R binding domain, RGS domain, interacts with Galpha.
# 10. NOL9: DLBCL, subtype, copynumber vairation
# 11. NACA: downregulated in melanoma
# 12. DMRTB1: Maybe testis?
# 13. ACTRT2: nothing significant
# 14. ITPR2: upregulated in AML
# 15. ACVRL1: ALK1, TGF receptor related. Found high mutation rate in prostate cancer. Kinase domain. TGF-beta expression related, so it is a interesting gene in prostate cancer
# 16. TPM2: Loss associated with RHOA activation in colorectal cancer. Isoforms found in breast cancer cell lines. downregulation of TPM is a sign of transformed cells.
#
# **Other questions to consider**
# 1. If mutaion in important protein domain?
# 2. The histology subtype
# 3. If the patients have other mutations, cnv, methylation
# 4. If mutation in other cancer patient dataset

# %% [markdown]
# **The histology subtypes of patients with the mutation**

# %%
# The sample information file
dir_refs = '../anno_ref/proc_refs'
df_info = pd.read_csv(os.path.join(dir_refs, 'PCAWG_sample_info.txt'), sep = '\t')

# %%
# MAF file
gene = 'XIRP2'
histology = df_syn.loc[gene,'feature']
df_maf = pd.read_csv(os.path.join(dir_maf,feature_type, histology+'.csv'), sep = '\t')
df_maf = df_maf.set_index(['Hugo_Symbol','Variant_Classification','Donor_ID' ])
df_gene_mut = df_maf.loc[pd.IndexSlice[gene, 'Silent',:],:]
# Out:
# /opt/aci/sw/anaconda3/2020.07_gcc-4.8.5-bzb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1,17,33,34,35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
histology
# Out:
# 'Skin-Melanoma'

# %%
df_gene_mut
# Out:
#                                             Chromosome  Start_position  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432           2       168107877
#                                    DO37435           2       168103758
#                                    DO37861           2       168105435
#                                    DO220907          2       168106770
#                                    DO220875          2       168100851
#                                    DO220864          2       168114592
#                                    DO37425           2       168104646
#                                    DO220883          2       168103809
#                                    DO37439           2       168102636
#                                    DO220903          2       168107877
#                                    DO220903          2       168108123
#                                    DO220886          2       168102090
#                                    DO220886          2       168103815
#                                    DO220886          2       168108054
#                                    DO220877          2       167760199
#                                    DO220877          2       168096370
#                                    DO37531           2       168107877
#                                    DO220860          2       167992481
#                                    DO220859          2       168100908
#                                    DO220891          2       168102048
#                                    DO220891          2       168106779
#                                    DO220913          2       168104508
#                                    DO47331           2       168115111
#                                    DO37599           2       168108159
#                                    DO37719           2       168105435
#                                    DO37719           2       168115072
#                                    DO37782           2       167760295
#                                    DO220905          2       168106371
#
#                                              End_position Strand Variant_Type  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432      168107877      +          SNP
#                                    DO37435      168103758      +          SNP
#                                    DO37861      168105435      +          SNP
#                                    DO220907     168106770      +          SNP
#                                    DO220875     168100851      +          SNP
#                                    DO220864     168114592      +          SNP
#                                    DO37425      168104646      +          SNP
#                                    DO220883     168103809      +          SNP
#                                    DO37439      168102636      +          SNP
#                                    DO220903     168107877      +          SNP
#                                    DO220903     168108123      +          SNP
#                                    DO220886     168102090      +          SNP
#                                    DO220886     168103815      +          SNP
#                                    DO220886     168108054      +          SNP
#                                    DO220877     167760199      +          SNP
#                                    DO220877     168096370      +          SNP
#                                    DO37531      168107877      +          SNP
#                                    DO220860     167992481      +          SNP
#                                    DO220859     168100908      +          SNP
#                                    DO220891     168102048      +          SNP
#                                    DO220891     168106779      +          SNP
#                                    DO220913     168104508      +          SNP
#                                    DO47331      168115111      +          SNP
#                                    DO37599      168108159      +          SNP
#                                    DO37719      168105435      +          SNP
#                                    DO37719      168115072      +          SNP
#                                    DO37782      167760295      +          SNP
#                                    DO220905     168106371      +          SNP
#
#                                             Reference_Allele  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432                 C
#                                    DO37435                 G
#                                    DO37861                 G
#                                    DO220907                G
#                                    DO220875                C
#                                    DO220864                A
#                                    DO37425                 G
#                                    DO220883                C
#                                    DO37439                 G
#                                    DO220903                C
#                                    DO220903                G
#                                    DO220886                G
#                                    DO220886                G
#                                    DO220886                G
#                                    DO220877                G
#                                    DO220877                A
#                                    DO37531                 C
#                                    DO220860                G
#                                    DO220859                G
#                                    DO220891                A
#                                    DO220891                G
#                                    DO220913                G
#                                    DO47331                 T
#                                    DO37599                 C
#                                    DO37719                 G
#                                    DO37719                 G
#                                    DO37782                 G
#                                    DO220905                G
#
#                                             Tumor_Seq_Allele1  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432                  C
#                                    DO37435                  G
#                                    DO37861                  G
#                                    DO220907                 G
#                                    DO220875                 C
#                                    DO220864                 A
#                                    DO37425                  G
#                                    DO220883                 C
#                                    DO37439                  G
#                                    DO220903                 C
#                                    DO220903                 G
#                                    DO220886                 G
#                                    DO220886                 G
#                                    DO220886                 G
#                                    DO220877                 G
#                                    DO220877                 A
#                                    DO37531                  C
#                                    DO220860                 G
#                                    DO220859                 G
#                                    DO220891                 A
#                                    DO220891                 G
#                                    DO220913                 G
#                                    DO47331                  T
#                                    DO37599                  C
#                                    DO37719                  G
#                                    DO37719                  G
#                                    DO37782                  G
#                                    DO220905                 G
#
#                                             Tumor_Seq_Allele2     dbSNP_RS  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432                  T          NaN
#                                    DO37435                  A          NaN
#                                    DO37861                  A          NaN
#                                    DO220907                 A          NaN
#                                    DO220875                 T  rs192182483
#                                    DO220864                 G          NaN
#                                    DO37425                  A          NaN
#                                    DO220883                 T          NaN
#                                    DO37439                  A          NaN
#                                    DO220903                 T          NaN
#                                    DO220903                 A  rs541668021
#                                    DO220886                 A          NaN
#                                    DO220886                 A          NaN
#                                    DO220886                 A          NaN
#                                    DO220877                 A          NaN
#                                    DO220877                 G          NaN
#                                    DO37531                  T          NaN
#                                    DO220860                 A          NaN
#                                    DO220859                 A          NaN
#                                    DO220891                 T          NaN
#                                    DO220891                 A          NaN
#                                    DO220913                 A          NaN
#                                    DO47331                  C          NaN
#                                    DO37599                  T          NaN
#                                    DO37719                  A          NaN
#                                    DO37719                  A          NaN
#                                    DO37782                  A          NaN
#                                    DO220905                 A          NaN
#
#                                             dbSNP_Val_Status  ...  \
# Hugo_Symbol Variant_Classification Donor_ID                   ...
# XIRP2       Silent                 DO37432               NaN  ...
#                                    DO37435               NaN  ...
#                                    DO37861               NaN  ...
#                                    DO220907              NaN  ...
#                                    DO220875      byFrequency  ...
#                                    DO220864              NaN  ...
#                                    DO37425               NaN  ...
#                                    DO220883              NaN  ...
#                                    DO37439               NaN  ...
#                                    DO220903              NaN  ...
#                                    DO220903              NaN  ...
#                                    DO220886              NaN  ...
#                                    DO220886              NaN  ...
#                                    DO220886              NaN  ...
#                                    DO220877              NaN  ...
#                                    DO220877              NaN  ...
#                                    DO37531               NaN  ...
#                                    DO220860              NaN  ...
#                                    DO220859              NaN  ...
#                                    DO220891              NaN  ...
#                                    DO220891              NaN  ...
#                                    DO220913              NaN  ...
#                                    DO47331               NaN  ...
#                                    DO37599               NaN  ...
#                                    DO37719               NaN  ...
#                                    DO37719               NaN  ...
#                                    DO37782               NaN  ...
#                                    DO220905              NaN  ...
#
#                                             i_signature_N3 i_signature_R1  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432           False          False
#                                    DO37435           False          False
#                                    DO37861           False          False
#                                    DO220907          False          False
#                                    DO220875          False          False
#                                    DO220864          False          False
#                                    DO37425           False          False
#                                    DO220883          False          False
#                                    DO37439           False          False
#                                    DO220903          False          False
#                                    DO220903          False          False
#                                    DO220886          False          False
#                                    DO220886          False          False
#                                    DO220886          False          False
#                                    DO220877          False          False
#                                    DO220877          False          False
#                                    DO37531           False          False
#                                    DO220860          False          False
#                                    DO220859          False          False
#                                    DO220891          False          False
#                                    DO220891          False          False
#                                    DO220913          False          False
#                                    DO47331           False          False
#                                    DO37599           False          False
#                                    DO37719           False          False
#                                    DO37719           False          False
#                                    DO37782           False          False
#                                    DO220905          False          False
#
#                                             i_signature_R2 i_snv_near_indel  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432           False            False
#                                    DO37435           False            False
#                                    DO37861           False            False
#                                    DO220907          False            False
#                                    DO220875          False            False
#                                    DO220864          False            False
#                                    DO37425           False            False
#                                    DO220883          False            False
#                                    DO37439           False            False
#                                    DO220903          False            False
#                                    DO220903          False            False
#                                    DO220886          False            False
#                                    DO220886          False            False
#                                    DO220886          False            False
#                                    DO220877          False            False
#                                    DO220877          False            False
#                                    DO37531           False            False
#                                    DO220860          False            False
#                                    DO220859          False            False
#                                    DO220891          False            False
#                                    DO220891          False            False
#                                    DO220913          False            False
#                                    DO47331           False            False
#                                    DO37599           False            False
#                                    DO37719           False            False
#                                    DO37719           False            False
#                                    DO37782           False            False
#                                    DO220905          False            False
#
#                                              t_alt_count t_ref_count  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432          12.0        21.0
#                                    DO37435          18.0        29.0
#                                    DO37861           6.0        32.0
#                                    DO220907         61.0        55.0
#                                    DO220875         32.0        64.0
#                                    DO220864         10.0        80.0
#                                    DO37425           8.0        28.0
#                                    DO220883         32.0        51.0
#                                    DO37439           8.0        35.0
#                                    DO220903         19.0        95.0
#                                    DO220903         76.0        44.0
#                                    DO220886         17.0        15.0
#                                    DO220886         20.0        13.0
#                                    DO220886          7.0        41.0
#                                    DO220877         30.0        47.0
#                                    DO220877         33.0        38.0
#                                    DO37531           8.0        23.0
#                                    DO220860          8.0        69.0
#                                    DO220859         14.0        20.0
#                                    DO220891         26.0        27.0
#                                    DO220891         27.0        33.0
#                                    DO220913         22.0        42.0
#                                    DO47331           9.0        23.0
#                                    DO37599          34.0        35.0
#                                    DO37719          13.0        38.0
#                                    DO37719           9.0        49.0
#                                    DO37782          28.0        63.0
#                                    DO220905         42.0         3.0
#
#                                             i_model_score i_n_vaf  \
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432            NaN     NaN
#                                    DO37435            NaN     NaN
#                                    DO37861            NaN     NaN
#                                    DO220907           NaN     NaN
#                                    DO220875           NaN     NaN
#                                    DO220864           NaN     NaN
#                                    DO37425            NaN     NaN
#                                    DO220883           NaN     NaN
#                                    DO37439            NaN     NaN
#                                    DO220903           NaN     NaN
#                                    DO220903           NaN     NaN
#                                    DO220886           NaN     NaN
#                                    DO220886           NaN     NaN
#                                    DO220886           NaN     NaN
#                                    DO220877           NaN     NaN
#                                    DO220877           NaN     NaN
#                                    DO37531            NaN     NaN
#                                    DO220860           NaN     NaN
#                                    DO220859           NaN     NaN
#                                    DO220891           NaN     NaN
#                                    DO220891           NaN     NaN
#                                    DO220913           NaN     NaN
#                                    DO47331            NaN     NaN
#                                    DO37599            NaN     NaN
#                                    DO37719            NaN     NaN
#                                    DO37719            NaN     NaN
#                                    DO37782            NaN     NaN
#                                    DO220905           NaN     NaN
#
#                                               Project_Code  categ
# Hugo_Symbol Variant_Classification Donor_ID
# XIRP2       Silent                 DO37432   Skin-Melanoma      3
#                                    DO37435   Skin-Melanoma      3
#                                    DO37861   Skin-Melanoma      3
#                                    DO220907  Skin-Melanoma      3
#                                    DO220875  Skin-Melanoma      3
#                                    DO220864  Skin-Melanoma      5
#                                    DO37425   Skin-Melanoma      3
#                                    DO220883  Skin-Melanoma      3
#                                    DO37439   Skin-Melanoma      3
#                                    DO220903  Skin-Melanoma      3
#                                    DO220903  Skin-Melanoma      3
#                                    DO220886  Skin-Melanoma      3
#                                    DO220886  Skin-Melanoma      3
#                                    DO220886  Skin-Melanoma      3
#                                    DO220877  Skin-Melanoma      3
#                                    DO220877  Skin-Melanoma      5
#                                    DO37531   Skin-Melanoma      3
#                                    DO220860  Skin-Melanoma      3
#                                    DO220859  Skin-Melanoma      3
#                                    DO220891  Skin-Melanoma      6
#                                    DO220891  Skin-Melanoma      3
#                                    DO220913  Skin-Melanoma      3
#                                    DO47331   Skin-Melanoma      5
#                                    DO37599   Skin-Melanoma      3
#                                    DO37719   Skin-Melanoma      3
#                                    DO37719   Skin-Melanoma      3
#                                    DO37782   Skin-Melanoma      3
#                                    DO220905  Skin-Melanoma      3
#
# [28 rows x 41 columns]

# %%
ldonor = df_gene_mut.index.get_level_values('Donor_ID').unique().tolist()

# %%
#histology tier3, 4, tumour_histological_type, SV.event, Coding.SNVs, CNA.events..do_not_use.
# Interested in: All patients' histology (event number)in this cohort, patients with mutation in this gene,  syn patient

### All patients' specific histology in this histology type
df_histology = df_info[df_info['histology_abbreviation'] == histology]
df_histology_syn = df_histology[df_histology['icgc_donor_id'].isin(ldonor)]

# %%
pd.concat({'syn': df_histology_syn[num_cols].describe()}, names=['mut_status'])
pd.concat({'all': df_histology[num_cols].describe()}, names=['mut_status'])
# Out:
#                     SV.events  Coding.SNVs  Non.coding.SNVs  \
# mut_status
# all        count   106.000000   107.000000       107.000000
#            mean    182.490566   803.971963    112468.271028
#            std     213.635080  1008.382232    144315.255781
#            min      12.000000    20.000000      2126.000000
#            25%      49.250000   121.500000     17297.000000
#            50%      98.000000   496.000000     70331.000000
#            75%     242.750000   932.500000    138316.500000
#            max    1234.000000  5164.000000    854014.000000
#
#                   CNA.events..do_not_use.  Retrotransposon.insertions  \
# mut_status
# all        count               107.000000                  107.000000
#            mean                487.065421                    4.990654
#            std                 461.390500                   34.356756
#            min                 118.000000                    0.000000
#            25%                 202.000000                    0.000000
#            50%                 317.000000                    0.000000
#            75%                 636.000000                    2.000000
#            max                3128.000000                  355.000000
#
#                   Mitochondrial.mutations    all.Indels
# mut_status
# all        count               107.000000    107.000000
#            mean                  2.168224   1000.140187
#            std                   1.840252   2274.979637
#            min                   0.000000     79.000000
#            25%                   1.000000    401.000000
#            50%                   2.000000    556.000000
#            75%                   3.000000    900.000000
#            max                   8.000000  22963.000000

# %%
df_num_summ = pd.concat([pd.concat({'syn': df_histology_syn[num_cols].describe()}, names=['mut_status'])\
,pd.concat({'all': df_histology[num_cols].describe()}, names=['mut_status'])])

# %%
num_cols = ['SV.events','Coding.SNVs', 'Non.coding.SNVs','CNA.events..do_not_use.', 'Retrotransposon.insertions',\
            'Mitochondrial.mutations','all.Indels']
str_cols = ['dcc_specimen_type','histology_tier3','histology_tier4',
        'tumour_histological_type',\
       'tumour_stage', 'tumour_histological_comment', 'specimen_donor_treatment_type']

# %%
df_str_info = pd.DataFrame(columns = str_cols, index = ['syn', 'all'])
for columns in str_cols:
    if columns not in ['icgc_donor_id','histology_abbreviation','histology_tier2']:
        
        df_str_info.loc['all', columns] = str(dict(Counter(df_histology[columns].tolist())))
        df_str_info.loc['syn', columns] = str(dict(Counter(df_histology_syn[columns].tolist())))

# %%
df_str_info
# Out:
#     icgc_donor_id                                  dcc_specimen_type  \
# syn           NaN  {'Metastatic tumour - NOS': 9, 'Metastatic tum...
# all           NaN  {'Metastatic tumour - NOS': 35, 'Metastatic tu...
#
#     histology_abbreviation histology_tier2    histology_tier3  \
# syn                    NaN             NaN   {'Melanoma': 22}
# all                    NaN             NaN  {'Melanoma': 107}
#
#                  histology_tier4          tumour_histological_type  \
# syn   {'Malignant melanoma': 22}   {'Malignant melanoma, NOS': 22}
# all  {'Malignant melanoma': 107}  {'Malignant melanoma, NOS': 107}
#
#                                tumour_stage tumour_histological_comment  \
# syn            {nan: 10, 'IV': 8, 'III': 4}                   {nan: 22}
# all  {nan: 37, 'III': 46, 'IV': 23, 'I': 1}                  {nan: 107}
#
#                     specimen_donor_treatment_type
# syn  {nan: 10, 'surgery': 11, 'other therapy': 1}
# all  {nan: 37, 'surgery': 67, 'other therapy': 3}
