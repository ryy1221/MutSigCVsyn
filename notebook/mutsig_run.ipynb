# %%
# This script is for running MutSig 
import matlab.engine
import os
import shutil
import time
import matlab.engine
eng = matlab.engine.start_matlab()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-be13faa61b03> in <module>
#       4 import shutil
#       5 import time
# ----> 6 import matlab.engine
#       7 from collections import Counter
#       8 eng = matlab.engine.start_matlab()
#
# ModuleNotFoundError: No module named 'matlab'

# %%
covariates = '../anno_ref/gene.covariates.converted.txt'
mut_dic = '../anno_ref/mutation_type_dictionary_file.txt'
chain_f = '../anno_ref/chr_files_hg19'
org_dir = '../org_cov_maf'
his_dir = '../his_cov_maf'
out_dir = '../mutsig_out/'

# %%
def runMutSig(org, syn):
    
    global covariates, mut_dic, chain_f, org_dir,his_dir,out_dir
    
    # if organ mode than use organ directory, if not then histology directory
    if org:
        tdir = org_dir
    else:
        tdir = his_dir
    listf = os.listdir(tdir)
    
    # get input maf and coverage files
    for folders in listf:
        start = time.time()
        organ = folders
        
        if os.path.isdir(os.path.join(tdir,folders)):
            # get input file in folder, set maf and coverage input to false
            list_input = os.listdir(os.path.join(tdir, folders))
            maf_input = False
            cov_input = False
            # find inputs
            for fs in list_input:
                if fs.endswith('maf'):  # maf file
                    maf_input = os.path.join(tdir, folders, fs)
                elif fs == 'merged_'+organ+'_102120.txt':
                    cov_input = os.path.join(tdir, folders, fs)
                elif fs.startswith('.'):
                    pass
                
            # check if both input exists
            if not (maf_input and cov_input):
                print "NO COVERAGE OR NO MAF FILE: " + organ
                continue

            # if syn
            if syn:
                out_p = os.path.join(out_dir,'syn','out10212020', organ, organ)
                try:
                    list_out = os.listdir(os.path.join(out_dir,'syn','out10212020', organ))
                    if organ+'.sig_genes.txt' in list_out:
                        print "NOT RUNNING DONE FOR: "+organ
                        continue
                except OSError:
                    pass
                # run matlab code
                print maf_input
                print cov_input
                print covariates
                print out_p
                print mut_dic
                print chain_f
                eng.cd(r'../mutsigsyn/', nargout = 0)
                eng.MutSigCVs_nbg(maf_input,cov_input, covariates, out_p, mut_dic, chain_f, nargout = 0)
                end = time.time()
                print "TIME USED FOR "+ organ+ " is "+ str(end-start)
                
            else:
                out_p = os.path.join(out_dir,'nsyn','out10212020', organ, organ)
                try:
                    list_out = os.listdir(os.path.join(out_dir,'nsyn','out10212020', organ))
                    if organ+'.sig_genes.txt' in list_out:
                        print "NOT RUNNING DONE FOR: "+organ
                        continue
                except OSError:
                    pass
                # run matlab code
                print maf_input
                print cov_input
                eng.cd(r'../mutsig/', nargout = 0)
                eng.MutSigCV_nbg(maf_input,cov_input, covariates, out_p, mut_dic, chain_f, nargout = 0)
                end = time.time()
                print "TIME USED FOR "+ organ+ " is "+ str(end-start)

# %%
runMutSig(org=True, syn = True)
# Out:
# ../org_cov_maf/Ovary/merged_tumor_covmerged_Ovary.txt_filtered.maf
# ../org_cov_maf/Ovary/merged_Ovary_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Ovary/Ovary
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Ovary is 605.034476042
# NOT RUNNING DONE FOR: Thy
# NOT RUNNING DONE FOR: Biliary
# NOT RUNNING DONE FOR: Breast
# ../org_cov_maf/Panc/merged_tumor_covmerged_Panc.txt_filtered.maf
# ../org_cov_maf/Panc/merged_Panc_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Panc/Panc
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Panc is 1430.50405717
# ../org_cov_maf/Lung/merged_tumor_covmerged_Lung.txt_filtered.maf
# ../org_cov_maf/Lung/merged_Lung_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Lung/Lung
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Lung is 1354.10972905
# ../org_cov_maf/Liver/merged_tumor_covmerged_Liver.txt_filtered.maf
# ../org_cov_maf/Liver/merged_Liver_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Liver/Liver
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Liver is 2118.4678278
# ../org_cov_maf/CNS/merged_tumor_covmerged_CNS.txt_filtered.maf
# ../org_cov_maf/CNS/merged_CNS_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/CNS/CNS
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR CNS is 937.85929513
# ../org_cov_maf/Lymph/merged_tumor_covmerged_Lymph.txt_filtered.maf
# ../org_cov_maf/Lymph/merged_Lymph_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Lymph/Lymph
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Lymph is 973.631554127
# NOT RUNNING DONE FOR: Bone
# NOT RUNNING DONE FOR: Eso
# ../org_cov_maf/ColoRect/merged_tumor_covmerged_ColoRect.txt_filtered.maf
# ../org_cov_maf/ColoRect/merged_ColoRect_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/ColoRect/ColoRect
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR ColoRect is 3047.926687
# ../org_cov_maf/Kidney/merged_tumor_covmerged_Kidney.txt_filtered.maf
# ../org_cov_maf/Kidney/merged_Kidney_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Kidney/Kidney
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Kidney is 827.95973587
# ../org_cov_maf/Myeloid/merged_tumor_covmerged_Myeloid.txt_filtered.maf
# ../org_cov_maf/Myeloid/merged_Myeloid_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Myeloid/Myeloid
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Myeloid is 160.102014065
# ../org_cov_maf/Stomach/merged_tumor_covmerged_Stomach.txt_filtered.maf
# ../org_cov_maf/Stomach/merged_Stomach_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Stomach/Stomach
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Stomach is 811.866292
# ../org_cov_maf/Prost/merged_tumor_covmerged_Prost.txt_filtered.maf
# ../org_cov_maf/Prost/merged_Prost_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Prost/Prost
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Prost is 682.217950106
# ../org_cov_maf/Skin/merged_tumor_covmerged_Skin.txt_filtered.maf
# ../org_cov_maf/Skin/merged_Skin_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Skin/Skin
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Skin is 4314.18480897
# ../org_cov_maf/Head/merged_tumor_covmerged_Head.txt_filtered.maf
# ../org_cov_maf/Head/merged_Head_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Head/Head
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Head is 504.190967083
# ../org_cov_maf/Uterus/merged_tumor_covmerged_Uterus.txt_filtered.maf
# ../org_cov_maf/Uterus/merged_Uterus_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Uterus/Uterus
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Uterus is 505.183459044
# NO COVERAGE OR NO MAF FILE: SoftTissue
# ../org_cov_maf/Cervix/merged_tumor_covmerged_Cervix.txt_filtered.maf
# ../org_cov_maf/Cervix/merged_Cervix_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Cervix/Cervix
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Cervix is 152.662464142
# ../org_cov_maf/Bladder/merged_tumor_covmerged_Bladder.txt_filtered.maf
# ../org_cov_maf/Bladder/merged_Bladder_102120.txt
# ../anno_ref/gene.covariates.converted.txt
# ../mutsig_out/syn/out10212020/Bladder/Bladder
# ../anno_ref/mutation_type_dictionary_file.txt
# ../anno_ref/chr_files_hg19
# TIME USED FOR Bladder is 263.949990034
